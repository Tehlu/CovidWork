# %%
import pandas as pd

# %%
cov=pd.read_csv("owid-covid-data.csv")

# %%
cov.head(3)
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2/24/2020          1.0        1.0
# 1      AFG      Asia  Afghanistan  2/25/2020          1.0        0.0
# 2      AFG      Asia  Afghanistan  2/26/2020          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
cov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72337 entries, 0 to 72336
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               72337 non-null  object
#  1   continent                              68748 non-null  object
#  2   location                               72337 non-null  object
#  3   date                                   72337 non-null  object
#  4   total_cases                            71331 non-null  float64
#  5   new_cases                              71329 non-null  float64
#  6   new_cases_smoothed                     70328 non-null  float64
#  7   total_deaths                           62230 non-null  float64
#  8   new_deaths                             62388 non-null  float64
#  9   new_deaths_smoothed                    70328 non-null  float64
# ...

# %%
cov.shape
# Out:
# (72337, 59)

# %%
cov.size
# Out:
# 4267883

# %%
cov.dropna(how='all',inplace=False)
# Out:
#       iso_code continent     location       date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2/24/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  2/25/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  2/26/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  2/27/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  2/28/2020          1.0        0.0
# ...        ...       ...          ...        ...          ...        ...
# 72332      ZWE    Africa     Zimbabwe  2/26/2021      36044.0       50.0
# 72333      ZWE    Africa     Zimbabwe  2/27/2021      36058.0       14.0
# 72334      ZWE    Africa     Zimbabwe  2/28/2021      36089.0       31.0
# 72335      ZWE    Africa     Zimbabwe   3/1/2021      36115.0       26.0
# 72336      ZWE    Africa     Zimbabwe   3/2/2021      36148.0       33.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
cov.dropna(how="any")
# Out:
# Empty DataFrame
# ...

# %%
cov.head(3)
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2/24/2020          1.0        1.0
# 1      AFG      Asia  Afghanistan  2/25/2020          1.0        0.0
# 2      AFG      Asia  Afghanistan  2/26/2020          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# ...
